# %%
import matplotlib.pyplot as plt

# Sample data
data_volume = [100, 200, 300, 400, 500]  # Data volume (x-axis values) in GB
throughput = [10, 15, 20, 18, 22]  # Throughput (y-axis values) in MB/s

# Create a plot
plt.figure(figsize=(10, 6))
plt.plot(data_volume, throughput, marker='o')

# Add labels and title
plt.xlabel('Data Volume (GB)')
plt.ylabel('Throughput (MB/s)')
plt.title('Throughput vs Data Volume')

# Show the plot
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
# import seaborn as sns  
# sns.set_style("whitegrid")
with plt.style.context("seaborn-poster"):
    plt.rcParams["font.family"] = "avenir"
    #plt.rcParams.update({'font.size': 16})  # Adjust the value as needed
#     plt.rcParams["font.size"] = 22  # Increase font size
    # Sample data
    end_delta = 1.5
    tasks = [
        'Hyperspectral\nImaging    ',
        'Spatiotemporal\nImaging     '
    ]
    subtask_names = ["Transfer", "Compute", "Search", "End"]
    subtasks = [
        [('Transfer', 0, 15), ('Compute', 15, 19), ('Search', 19, 32), ('End', 32, 32 + end_delta)],
        [('Transfer', 0, 140), ('Compute', 140, 187), ('Search', 187, 210), ('End', 210, 210 + end_delta)],
    ]
    #colors = ['b', 'g', 'r', 'c']  # Colors for subtasks
    #colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']
    colors = ['#a6cee3', '#1f78b4', '#b2df8a', '#33a02c'] 

    # Create a horizontal bar chart with subtasks
    plt.figure(figsize=(12, 6))

    # Add grid lines
    plt.grid(True, linestyle='--', linewidth=1, alpha=0.7, zorder=1)

    y_positions = [0.55, 0.6]  # Adjusted y-positions to bring the bars closer
    for i, (y_position, task, subtask_list) in enumerate(zip(y_positions, tasks, subtasks)):
        for (subtask, start, end), color in zip(subtask_list, colors):
            # Plot the subtask bars
            plt.barh(y_position, end - start, height=0.03, left=start, color=color, label=subtask, zorder=2)

    # Set x-axis label
    plt.xlabel('Elapsed Time (s)', fontsize=22)

    # Set y-axis label
    plt.yticks(y_positions, tasks, fontsize=22)  # Setting y-ticks for task labels
    plt.xticks(fontsize=22)
    # plt.ylabel('Tasks')

    # Set chart title
    #plt.title('Horizontal Bar Chart with Subtasks')

    # Create the legend with unique handles and labels
    legend_handles = [plt.Rectangle((0, 0), 1, 1, color=color) for color in colors]
    plt.legend(legend_handles, subtask_names, loc='upper left', bbox_to_anchor=(1, 1), fontsize=22)
    
#     plt.rcParams.update({'font.size': 55})

    plt.tight_layout()
    plt.savefig('flow-runtime2.pdf', dpi=600, bbox_inches="tight")
    plt.show()

# %%
import pickle

class FlowInfoDataClass:
    def __init__(self):
        self.flow_id = None
        self.flow_scope = None
        self.flow_runs = []
        self.flow_order = []
        self.flow_logs = {}
        self.action_logs = {}

with open("performance_49af5d02-6d4d-4bf9-9666-813a9f2e106f.pkl", "rb") as f:
    data = pickle.load(f)

# %%
data.flow_runs
# Out:
# [{'run_id': '0895a642-5eda-4a62-9d4a-c1372a544043',
#   'flow_id': '49af5d02-6d4d-4bf9-9666-813a9f2e106f',
#   'flow_title': 'PicoProbeTemporalImaging_Production_v2 flow',
#   'flow_last_updated': '2023-08-20T20:38:51.712933+00:00',
#   'start_time': '2023-08-20T21:36:24.315778+00:00',
#   'completion_time': '2023-08-20T21:40:25.066000+00:00',
#   'status': 'SUCCEEDED',
#   'display_status': 'SUCCEEDED',
#   'details': {'code': 'FlowSucceeded',
#    'output': {'input': {'publishv2': {'index': '06625170-a9ee-4d68-b8dc-2480c9407966',
#       'dataset': '/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164652',
#       'metadata': {},
#       'visible_to': ['public'],
#       'destination': '/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164652',
#       'ingest_enabled': True,
#       'transfer_enabled': False,
#       'source_collection': '300ef593-e55e-4bc1-ab21-6d26d82c3b99',
#       'destination_collection': '300ef593-e55e-4bc1-ab21-6d26d82c3b99'},
#      'yolo_model_path': '/lus/eagle/projects/CVD-Mol-AI/braceal/tmp-space/best-yolo.pt',
#      'transfer_recursive': False,
#      'transfer_sync_level': 'checksum',
#      'transfer_source_path': 'MicroscopeData/Brace/transfers/simulator-19-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.emd',
#      'funcx_endpoint_compute': 'd8e16504-eaab-44b6-aa56-ff7d1b6040a3',
#      'transfer_destination_path': 'PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164652/simulator-19-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.emd',
#      'funcx_endpoint_non_compute': 'f53c4fe3-1293-4baa-bdb0-118fab4e56ef',
#      'transfer_source_endpoint_id': '387aaf6e-3302-11ee-9200-5b20905a64b1',
#      'temporal_image_tool_funcx_id': '6de4d675-a11c-4def-bda1-d69d69c47a8b',
#      'transfer_destination_endpoint_id': '300ef593-e55e-4bc1-ab21-6d26d82c3b99',
#      'publishv2_gather_metadata_funcx_id': 'c73884b4-8f90-4846-aaa1-0fde37b5ced1'},
#     'Transfer': {'label': None,
#      'status': 'SUCCEEDED',
#      'details': {'type': 'TRANSFER',
#       'files': 1,
#       'is_ok': None,
#       'label': 'For Action id 30yaR8rKdTCi',
#       'faults': 0,
#       'status': 'SUCCEEDED',
#       'command': 'API 0.10',
#       'task_id': 'a1dcba34-3fa1-11ee-88f9-03dc0e0dcc45',
#       'deadline': '2023-08-21T21:36:34+00:00',
#       'owner_id': 'cc36c658-d274-11e5-97a2-8fe5433dd97e',
#       'symlinks': 0,
#       'username': 'zaluzec',
#       'DATA_TYPE': 'task',
#       'is_paused': False,
#       'event_list': [{'code': 'SUCCEEDED',
#         'time': '2023-08-20T21:38:26+00:00',
#         'details': {'files_succeeded': 1},
#         'is_error': False,
#         'DATA_TYPE': 'event',
#         'description': 'succeeded'},
#        {'code': 'PROGRESS',
#         'time': '2023-08-20T21:38:26+00:00',
#         'details': {'mbps': 94.68,
#          'duration': 49.52,
#          'bytes_transferred': 586048419},
#         'is_error': False,
#         'DATA_TYPE': 'event',
#         'description': 'progress'},
#        {'code': 'PROGRESS',
#         'time': '2023-08-20T21:37:36+00:00',
#         'details': {'mbps': 93.28,
#          'duration': 60.84,
#          'bytes_transferred': 709361664},
#         'is_error': False,
#         'DATA_TYPE': 'event',
#         'description': 'progress'},
#        {'code': 'STARTED',
#         'time': '2023-08-20T21:36:35+00:00',
#         'details': {'type': 'GridFTP Transfer',
#          'pipelining': 20,
#          'concurrency': 4,
#          'parallelism': 4},
#         'is_error': False,
#         'DATA_TYPE': 'event',
#         'description': 'started'}],
#       'sync_level': None,
#       'directories': 0,
#       'fatal_error': None,
#       'nice_status': None,
#       'encrypt_data': False,
#       'filter_rules': None,
#       'request_time': '2023-08-20T21:36:34+00:00',
#       'files_skipped': 0,
#       'subtasks_total': 2,
#       'completion_time': '2023-08-20T21:38:26+00:00',
#       'history_deleted': False,
#       'source_endpoint': 'zaluzec#387aaf6e-3302-11ee-9200-5b20905a64b1',
#       'subtasks_failed': 0,
#       'verify_checksum': False,
#       'source_base_path': None,
#       'subtasks_expired': 0,
#       'subtasks_pending': 0,
#       'bytes_checksummed': 0,
#       'bytes_transferred': 1295410083,
#       'canceled_by_admin': None,
#       'files_transferred': 1,
#       'subtasks_canceled': 0,
#       'subtasks_retrying': 0,
#       'preserve_timestamp': False,
#       'recursive_symlinks': 'ignore',
#       'skip_source_errors': False,
#       'source_endpoint_id': '387aaf6e-3302-11ee-9200-5b20905a64b1',
#       'subtasks_succeeded': 2,
#       'nice_status_details': None,
#       'destination_endpoint': 'u_ei35ibphljgubnttgfktzs6k2m#655f5140-370f-11ee-b54c-e72de9e39f95',
#       'fail_on_quota_errors': False,
#       'destination_base_path': None,
#       'nice_status_expires_in': None,
#       'destination_endpoint_id': '300ef593-e55e-4bc1-ab21-6d26d82c3b99',
#       'subtasks_skipped_errors': 0,
#       'delete_destination_extra': False,
#       'canceled_by_admin_message': None,
#       'effective_bytes_per_second': 11579330,
#       'source_endpoint_display_name': 'PicoProbeUserDAComputer',
#       'nice_status_short_description': None,
#       'destination_endpoint_display_name': 'Gladier-PicoProbe'},
#      'action_id': '30yaR8rKdTCi',
#      'manage_by': [],
#      'creator_id': 'urn:globus:auth:identity:cc36c658-d274-11e5-97a2-8fe5433dd97e',
#      'monitor_by': [],
#      'start_time': '2023-08-20T21:36:33.423866+00:00',
#      'state_name': 'Transfer',
#      'release_after': 'P30D',
#      'display_status': 'SUCCEEDED',
#      'completion_time': '2023-08-20T21:36:33.423888+00:00'},
#     'Publishv2Ingest': {'label': None,
#      'status': 'SUCCEEDED',
#      'details': {'state': 'SUCCESS',
#       'message': None,
#       'task_id': '406bf167-4c14-4d4c-926e-d77c44c550ad',
#       'index_id': '06625170-a9ee-4d68-b8dc-2480c9407966',
#       'task_type': 'ingest',
#       'creation_date': '2023-08-20T21:40:21',
#       'completion_date': '2023-08-20T21:40:21',
#       'state_description': 'Task succeeded',
#       'additional_details': None},
#      'action_id': '1DSsnDwQ0L0fD',
#      'manage_by': [],
#      'creator_id': 'urn:globus:auth:identity:cc36c658-d274-11e5-97a2-8fe5433dd97e',
#      'monitor_by': [],
#      'start_time': '2023-08-20T21:40:21.330674+00:00',
#      'state_name': 'Publishv2Ingest',
#      'release_after': None,
#      'display_status': 'Task succeeded',
#      'completion_time': '2023-08-20T21:40:21'},
#     'TemporalImageTool': {'label': None,
#      'status': 'SUCCEEDED',
#      'details': {'result': [{'index': '06625170-a9ee-4d68-b8dc-2480c9407966',
#         'dataset': '/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164652',
#         'metadata': {'creators': [{'creatorName': 'PicoProbe Team'}],
#          'exp_type': 'picoprobe',
#          'subjects': [{'subject': 'PicoProbe'}],
#          'publisher': 'Argonne National Laboratory (ANL)',
#          'resourceType': {'resourceType': 'Dataset',
#           'resourceTypeGeneral': 'Dataset'},
#          'temporal_data': '/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164652/simulator-19-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.mp4',
#          'publicationYear': '2023',
#          'experiment_metadata': {'Signal': {'signal_type': ''},
#           'General': {'date': '2023-08-10',
#            'time': '23:19:28',
#            'title': 'Ceta',
#            'FileIO': {'0': {'io_plugin': 'hyperspy.io_plugins.emd',
#              'operation': 'load',
#              'timestamp': '2023-08-20T21:39:29.248297+00:00',
#              'hyperspy_version': '1.7.5'}},
#            'time_zone': 'UTC',
#            'original_filename': 'simulator-19-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.emd'},
#           '_HyperSpy': {'Folding': {'unfolded': False,
#             'original_shape': None,
#             'signal_unfolded': False,
#             'original_axes_manager': None}},
#           'Acquisition_instrument': {'TEM': {'Stage': {'x': -0.000247,
#              'y': 4.2e-05,
#              'z': 1.3e-05,
#              'tilt_beta': 0.0,
#              'tilt_alpha': 0.008},
#             'microscope': 'Titan',
#             'beam_energy': 300.0,
#             'camera_length': 75.0,
#             'magnification': 0.0}}},
#          'temporal_prediction_data': '/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164652/prediction-simulator-19-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.mp4'},
#         'visible_to': ['public'],
#         'destination': '/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164652',
#         'ingest_enabled': True,
#         'transfer_enabled': False,
#         'source_collection': '300ef593-e55e-4bc1-ab21-6d26d82c3b99',
#         'destination_collection': '300ef593-e55e-4bc1-ab21-6d26d82c3b99'}],
#       'results': [{'output': {'index': '06625170-a9ee-4d68-b8dc-2480c9407966',
#          'dataset': '/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164652',
#          'metadata': {'creators': [{'creatorName': 'PicoProbe Team'}],
#           'exp_type': 'picoprobe',
#           'subjects': [{'subject': 'PicoProbe'}],
#           'publisher': 'Argonne National Laboratory (ANL)',
#           'resourceType': {'resourceType': 'Dataset',
#            'resourceTypeGeneral': 'Dataset'},
#           'temporal_data': '/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164652/simulator-19-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.mp4',
#           'publicationYear': '2023',
#           'experiment_metadata': {'Signal': {'signal_type': ''},
#            'General': {'date': '2023-08-10',
#             'time': '23:19:28',
#             'title': 'Ceta',
#             'FileIO': {'0': {'io_plugin': 'hyperspy.io_plugins.emd',
#               'operation': 'load',
#               'timestamp': '2023-08-20T21:39:29.248297+00:00',
#               'hyperspy_version': '1.7.5'}},
#             'time_zone': 'UTC',
#             'original_filename': 'simulator-19-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.emd'},
#            '_HyperSpy': {'Folding': {'unfolded': False,
#              'original_shape': None,
#              'signal_unfolded': False,
#              'original_axes_manager': None}},
#            'Acquisition_instrument': {'TEM': {'Stage': {'x': -0.000247,
#               'y': 4.2e-05,
#               'z': 1.3e-05,
#               'tilt_beta': 0.0,
#               'tilt_alpha': 0.008},
#              'microscope': 'Titan',
#              'beam_energy': 300.0,
#              'camera_length': 75.0,
#              'magnification': 0.0}}},
#           'temporal_prediction_data': '/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164652/prediction-simulator-19-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.mp4'},
#          'visible_to': ['public'],
#          'destination': '/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164652',
#          'ingest_enabled': True,
#          'transfer_enabled': False,
#          'source_collection': '300ef593-e55e-4bc1-ab21-6d26d82c3b99',
#          'destination_collection': '300ef593-e55e-4bc1-ab21-6d26d82c3b99'},
#         'task_id': '274c4cd7-01a5-472c-a3d1-eef8420215a1'}]},
#      'action_id': 'tg_a166b5a5-91e3-483d-909f-fe23239f5b9f',
#      'manage_by': ['urn:globus:auth:identity:cc36c658-d274-11e5-97a2-8fe5433dd97e'],
#      'creator_id': 'urn:globus:auth:identity:cc36c658-d274-11e5-97a2-8fe5433dd97e',
#      'monitor_by': ['urn:globus:auth:identity:cc36c658-d274-11e5-97a2-8fe5433dd97e'],
#      'start_time': '2023-08-20T21:39:23.556360+00:00',
#      'state_name': 'TemporalImageTool',
#      'release_after': None,
#      'display_status': 'All tasks completed',
#      'completion_time': '2023-08-20T21:40:01.359978+00:00'},
#     'Publishv2GatherMetadata': {'label': None,
#      'status': 'SUCCEEDED',
#      'details': {'result': [{'search': {'id': 'metadata',
#          'content': {'dc': {'dates': [{'date': '2023-08-20T21:40:11.548926Z',
#              'dateType': 'Created'}],
#            'types': {'resourceType': 'Dataset',
#             'resourceTypeGeneral': 'Dataset'},
#            'titles': [{'title': '20230820-164652'}],
#            'formats': ['application/json',
#             'application/octet-stream',
#             'video/mp4'],
#            'version': '1',
#            'creators': [{'name': ''}],
#            'subjects': [],
#            'publisher': '',
#            'identifiers': [{'identifier': 'globus://300ef593-e55e-4bc1-ab21-6d26d82c3b99/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164652/20230820-164652',
#              'identifierType': 'GlobusSearchSubject'}],
#            'schemaVersion': 'http://datacite.org/schema/kernel-4',
#            'publicationYear': '2023'},
#           'files': [{'url': 'globus://300ef593-e55e-4bc1-ab21-6d26d82c3b99/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164652/20230820-164652/simulator-19-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.mp4',
#             'length': 58451712,
#             'sha256': 'e8d0aa41ecee6fcdbe3894d9535127c6bb1067ce6b5a9ad24af1b2a805d37ddd',
#             'sha512': '282a125ae0331453158b2d4795be71451ce9f0afceabdc02d5284497bb274d71b8d6eecb85b1bdc8c12743b76688fbcb83c8dddf67f1a34db19b240aeeba52bd',
#             'filename': 'simulator-19-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.mp4',
#             'mime_type': 'video/mp4'},
#            {'url': 'globus://300ef593-e55e-4bc1-ab21-6d26d82c3b99/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164652/20230820-164652/simulator-19-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.json',
#             'length': 3143,
#             'sha256': '345692ce20df769b7de34e01d4f8f1fdd37189ad3a803e0d3c076a0d68e6da92',
#             'sha512': 'd7254aeeb7087a819e6ac8d8fd1e9d1abb2ee936f63c71760724d1b2c8da136f0281586235855d00604d9081b3c855be5cdaff7be31b7294f4745bfff85b6345',
#             'filename': 'simulator-19-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.json',
#             'mime_type': 'application/json'},
#            {'url': 'globus://300ef593-e55e-4bc1-ab21-6d26d82c3b99/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164652/20230820-164652/simulator-19-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.emd',
#             'length': 1295410083,
#             'sha256': 'b312fe40d8e662d376fbdd05dd162401bc8d6d9b34b27015f23b2df930e3ef46',
#             'sha512': 'e1a5c8ee3d7a4aa20adfcaab5eda0b6cdbbb3386612730591b39f6417e8d927da98c7a569a07d90e2a9eff9a32dfa67c648ef7d3b18f828409c41b5260212818',
#             'filename': 'simulator-19-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.emd',
#             'mime_type': 'application/octet-stream'},
#            {'url': 'globus://300ef593-e55e-4bc1-ab21-6d26d82c3b99/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164652/20230820-164652/prediction-simulator-19-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.mp4',
#             'length': 161135611,
#             'sha256': '1e44b065795769d538bc7acc354aaba826e06f0a9c2874ad789e4f60c9b2fd34',
#             'sha512': '27d4af685cb6749b663d9f9fc8d69813d660591ce5e1ad5e685198cf6bf4c44f908ad849cb2fe0bf7f49b20eb7607739dabfc16473beaabda95168f499a1d4a5',
#             'filename': 'prediction-simulator-19-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.mp4',
#             'mime_type': 'video/mp4'}],
#           'creators': [{'creatorName': 'PicoProbe Team'}],
#           'exp_type': 'picoprobe',
#           'subjects': [{'subject': 'PicoProbe'}],
#           'publisher': 'Argonne National Laboratory (ANL)',
#           'resourceType': {'resourceType': 'Dataset',
#            'resourceTypeGeneral': 'Dataset'},
#           'temporal_data': '/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164652/simulator-19-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.mp4',
#           'publicationYear': '2023',
#           'experiment_metadata': {'Signal': {'signal_type': ''},
#            'General': {'date': '2023-08-10',
#             'time': '23:19:28',
#             'title': 'Ceta',
#             'FileIO': {'0': {'io_plugin': 'hyperspy.io_plugins.emd',
#               'operation': 'load',
#               'timestamp': '2023-08-20T21:39:29.248297+00:00',
#               'hyperspy_version': '1.7.5'}},
#             'time_zone': 'UTC',
#             'original_filename': 'simulator-19-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.emd'},
#            '_HyperSpy': {'Folding': {'unfolded': False,
#              'original_shape': None,
#              'signal_unfolded': False,
#              'original_axes_manager': None}},
#            'Acquisition_instrument': {'TEM': {'Stage': {'x': -0.000247,
#               'y': 4.2e-05,
#               'z': 1.3e-05,
#               'tilt_beta': 0.0,
#               'tilt_alpha': 0.008},
#              'microscope': 'Titan',
#              'beam_energy': 300.0,
#              'camera_length': 75.0,
#              'magnification': 0.0}}},
#           'temporal_prediction_data': '/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164652/prediction-simulator-19-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.mp4'},
#          'subject': 'globus://300ef593-e55e-4bc1-ab21-6d26d82c3b99/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164652/20230820-164652',
#          'visible_to': ['public'],
#          'search_index': '06625170-a9ee-4d68-b8dc-2480c9407966'},
#         'transfer': {'transfer_items': [{'source_path': '/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164652',
#            'destination_path': '/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164652/20230820-164652'}],
#          'source_endpoint_id': '300ef593-e55e-4bc1-ab21-6d26d82c3b99',
#          'destination_endpoint_id': '300ef593-e55e-4bc1-ab21-6d26d82c3b99'}}],
#       'results': [{'output': {'search': {'id': 'metadata',
#           'content': {'dc': {'dates': [{'date': '2023-08-20T21:40:11.548926Z',
#               'dateType': 'Created'}],
#             'types': {'resourceType': 'Dataset',
#              'resourceTypeGeneral': 'Dataset'},
#             'titles': [{'title': '20230820-164652'}],
#             'formats': ['application/json',
#              'application/octet-stream',
#              'video/mp4'],
#             'version': '1',
#             'creators': [{'name': ''}],
#             'subjects': [],
#             'publisher': '',
#             'identifiers': [{'identifier': 'globus://300ef593-e55e-4bc1-ab21-6d26d82c3b99/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164652/20230820-164652',
#               'identifierType': 'GlobusSearchSubject'}],
#             'schemaVersion': 'http://datacite.org/schema/kernel-4',
#             'publicationYear': '2023'},
#            'files': [{'url': 'globus://300ef593-e55e-4bc1-ab21-6d26d82c3b99/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164652/20230820-164652/simulator-19-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.mp4',
#              'length': 58451712,
#              'sha256': 'e8d0aa41ecee6fcdbe3894d9535127c6bb1067ce6b5a9ad24af1b2a805d37ddd',
#              'sha512': '282a125ae0331453158b2d4795be71451ce9f0afceabdc02d5284497bb274d71b8d6eecb85b1bdc8c12743b76688fbcb83c8dddf67f1a34db19b240aeeba52bd',
#              'filename': 'simulator-19-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.mp4',
#              'mime_type': 'video/mp4'},
#             {'url': 'globus://300ef593-e55e-4bc1-ab21-6d26d82c3b99/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164652/20230820-164652/simulator-19-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.json',
#              'length': 3143,
#              'sha256': '345692ce20df769b7de34e01d4f8f1fdd37189ad3a803e0d3c076a0d68e6da92',
#              'sha512': 'd7254aeeb7087a819e6ac8d8fd1e9d1abb2ee936f63c71760724d1b2c8da136f0281586235855d00604d9081b3c855be5cdaff7be31b7294f4745bfff85b6345',
#              'filename': 'simulator-19-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.json',
#              'mime_type': 'application/json'},
#             {'url': 'globus://300ef593-e55e-4bc1-ab21-6d26d82c3b99/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164652/20230820-164652/simulator-19-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.emd',
#              'length': 1295410083,
#              'sha256': 'b312fe40d8e662d376fbdd05dd162401bc8d6d9b34b27015f23b2df930e3ef46',
#              'sha512': 'e1a5c8ee3d7a4aa20adfcaab5eda0b6cdbbb3386612730591b39f6417e8d927da98c7a569a07d90e2a9eff9a32dfa67c648ef7d3b18f828409c41b5260212818',
#              'filename': 'simulator-19-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.emd',
#              'mime_type': 'application/octet-stream'},
#             {'url': 'globus://300ef593-e55e-4bc1-ab21-6d26d82c3b99/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164652/20230820-164652/prediction-simulator-19-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.mp4',
#              'length': 161135611,
#              'sha256': '1e44b065795769d538bc7acc354aaba826e06f0a9c2874ad789e4f60c9b2fd34',
#              'sha512': '27d4af685cb6749b663d9f9fc8d69813d660591ce5e1ad5e685198cf6bf4c44f908ad849cb2fe0bf7f49b20eb7607739dabfc16473beaabda95168f499a1d4a5',
#              'filename': 'prediction-simulator-19-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.mp4',
#              'mime_type': 'video/mp4'}],
#            'creators': [{'creatorName': 'PicoProbe Team'}],
#            'exp_type': 'picoprobe',
#            'subjects': [{'subject': 'PicoProbe'}],
#            'publisher': 'Argonne National Laboratory (ANL)',
#            'resourceType': {'resourceType': 'Dataset',
#             'resourceTypeGeneral': 'Dataset'},
#            'temporal_data': '/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164652/simulator-19-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.mp4',
#            'publicationYear': '2023',
#            'experiment_metadata': {'Signal': {'signal_type': ''},
#             'General': {'date': '2023-08-10',
#              'time': '23:19:28',
#              'title': 'Ceta',
#              'FileIO': {'0': {'io_plugin': 'hyperspy.io_plugins.emd',
#                'operation': 'load',
#                'timestamp': '2023-08-20T21:39:29.248297+00:00',
#                'hyperspy_version': '1.7.5'}},
#              'time_zone': 'UTC',
#              'original_filename': 'simulator-19-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.emd'},
#             '_HyperSpy': {'Folding': {'unfolded': False,
#               'original_shape': None,
#               'signal_unfolded': False,
#               'original_axes_manager': None}},
#             'Acquisition_instrument': {'TEM': {'Stage': {'x': -0.000247,
#                'y': 4.2e-05,
#                'z': 1.3e-05,
#                'tilt_beta': 0.0,
#                'tilt_alpha': 0.008},
#               'microscope': 'Titan',
#               'beam_energy': 300.0,
#               'camera_length': 75.0,
#               'magnification': 0.0}}},
#            'temporal_prediction_data': '/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164652/prediction-simulator-19-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.mp4'},
#           'subject': 'globus://300ef593-e55e-4bc1-ab21-6d26d82c3b99/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164652/20230820-164652',
#           'visible_to': ['public'],
#           'search_index': '06625170-a9ee-4d68-b8dc-2480c9407966'},
#          'transfer': {'transfer_items': [{'source_path': '/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164652',
#             'destination_path': '/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164652/20230820-164652'}],
#           'source_endpoint_id': '300ef593-e55e-4bc1-ab21-6d26d82c3b99',
#           'destination_endpoint_id': '300ef593-e55e-4bc1-ab21-6d26d82c3b99'}},
#         'task_id': '5fd2edfd-86e6-45a1-8531-df00cba8ffb2'}]},
#      'action_id': 'tg_8ba92069-8392-4ab2-b80d-e767937649dd',
#      'manage_by': ['urn:globus:auth:identity:cc36c658-d274-11e5-97a2-8fe5433dd97e'],
#      'creator_id': 'urn:globus:auth:identity:cc36c658-d274-11e5-97a2-8fe5433dd97e',
#      'monitor_by': ['urn:globus:auth:identity:cc36c658-d274-11e5-97a2-8fe5433dd97e'],
#      'start_time': '2023-08-20T21:40:02.516779+00:00',
#      'state_name': 'Publishv2GatherMetadata',
#      'release_after': None,
#      'display_status': 'All tasks completed',
#      'completion_time': '2023-08-20T21:40:19.937173+00:00'}},
#    'description': 'The Flow run reached a successful completion state'},
#   'run_owner': 'urn:globus:auth:identity:cc36c658-d274-11e5-97a2-8fe5433dd97e',
#   'run_managers': [],
#   'run_monitors': [],
#   'user_role': 'run_owner',
#   'label': 'Temporal simulator-19-2023081040-700kx MultiFrams 991ms 600F C..',
#   'tags': [],
#   'action_id': '0895a642-5eda-4a62-9d4a-c1372a544043',
#   'manage_by': [],
#   'monitor_by': [],
#   'created_by': 'urn:globus:auth:identity:cc36c658-d274-11e5-97a2-8fe5433dd97e'},
#  {'run_id': '764dba1a-cded-41d8-b766-d6232b0d3404',
#   'flow_id': '49af5d02-6d4d-4bf9-9666-813a9f2e106f',
#   'flow_title': 'PicoProbeTemporalImaging_Production_v2 flow',
#   'flow_last_updated': '2023-08-20T20:38:51.712933+00:00',
#   'start_time': '2023-08-20T21:33:22.645603+00:00',
#   'completion_time': '2023-08-20T21:36:42.360000+00:00',
#   'status': 'SUCCEEDED',
#   'display_status': 'SUCCEEDED',
#   'details': {'code': 'FlowSucceeded',
#    'output': {'input': {'publishv2': {'index': '06625170-a9ee-4d68-b8dc-2480c9407966',
#       'dataset': '/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164351',
#       'metadata': {},
#       'visible_to': ['public'],
#       'destination': '/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164351',
#       'ingest_enabled': True,
#       'transfer_enabled': False,
#       'source_collection': '300ef593-e55e-4bc1-ab21-6d26d82c3b99',
#       'destination_collection': '300ef593-e55e-4bc1-ab21-6d26d82c3b99'},
#      'yolo_model_path': '/lus/eagle/projects/CVD-Mol-AI/braceal/tmp-space/best-yolo.pt',
#      'transfer_recursive': False,
#      'transfer_sync_level': 'checksum',
#      'transfer_source_path': 'MicroscopeData/Brace/transfers/simulator-18-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.emd',
#      'funcx_endpoint_compute': 'd8e16504-eaab-44b6-aa56-ff7d1b6040a3',
#      'transfer_destination_path': 'PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164351/simulator-18-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.emd',
#      'funcx_endpoint_non_compute': 'f53c4fe3-1293-4baa-bdb0-118fab4e56ef',
#      'transfer_source_endpoint_id': '387aaf6e-3302-11ee-9200-5b20905a64b1',
#      'temporal_image_tool_funcx_id': '6de4d675-a11c-4def-bda1-d69d69c47a8b',
#      'transfer_destination_endpoint_id': '300ef593-e55e-4bc1-ab21-6d26d82c3b99',
#      'publishv2_gather_metadata_funcx_id': 'c73884b4-8f90-4846-aaa1-0fde37b5ced1'},
#     'Transfer': {'label': None,
#      'status': 'SUCCEEDED',
#      'details': {'type': 'TRANSFER',
#       'files': 1,
#       'is_ok': None,
#       'label': 'For Action id 1BAqWzijmZl1t',
#       'faults': 0,
#       'status': 'SUCCEEDED',
#       'command': 'API 0.10',
#       'task_id': '314c3784-3fa1-11ee-88f9-03dc0e0dcc45',
#       'deadline': '2023-08-21T21:33:24+00:00',
#       'owner_id': 'cc36c658-d274-11e5-97a2-8fe5433dd97e',
#       'symlinks': 0,
#       'username': 'zaluzec',
#       'DATA_TYPE': 'task',
#       'is_paused': False,
#       'event_list': [{'code': 'SUCCEEDED',
#         'time': '2023-08-20T21:35:27+00:00',
#         'details': {'files_succeeded': 1},
#         'is_error': False,
#         'DATA_TYPE': 'event',
#         'description': 'succeeded'},
#        {'code': 'PROGRESS',
#         'time': '2023-08-20T21:35:27+00:00',
#         'details': {'mbps': 99.53,
#          'duration': 0.5,
#          'bytes_transferred': 6185891},
#         'is_error': False,
#         'DATA_TYPE': 'event',
#         'description': 'progress'},
#        {'code': 'PROGRESS',
#         'time': '2023-08-20T21:35:27+00:00',
#         'details': {'mbps': 102.55,
#          'duration': 60.0,
#          'bytes_transferred': 769130496},
#         'is_error': False,
#         'DATA_TYPE': 'event',
#         'description': 'progress'},
#        {'code': 'PROGRESS',
#         'time': '2023-08-20T21:34:27+00:00',
#         'details': {'mbps': 68.4,
#          'duration': 60.83,
#          'bytes_transferred': 520093696},
#         'is_error': False,
#         'DATA_TYPE': 'event',
#         'description': 'progress'},
#        {'code': 'STARTED',
#         'time': '2023-08-20T21:33:26+00:00',
#         'details': {'type': 'GridFTP Transfer',
#          'pipelining': 20,
#          'concurrency': 4,
#          'parallelism': 4},
#         'is_error': False,
#         'DATA_TYPE': 'event',
#         'description': 'started'}],
#       'sync_level': None,
#       'directories': 0,
#       'fatal_error': None,
#       'nice_status': None,
#       'encrypt_data': False,
#       'filter_rules': None,
#       'request_time': '2023-08-20T21:33:25+00:00',
#       'files_skipped': 0,
#       'subtasks_total': 2,
#       'completion_time': '2023-08-20T21:35:27+00:00',
#       'history_deleted': False,
#       'source_endpoint': 'zaluzec#387aaf6e-3302-11ee-9200-5b20905a64b1',
#       'subtasks_failed': 0,
#       'verify_checksum': False,
#       'source_base_path': None,
#       'subtasks_expired': 0,
#       'subtasks_pending': 0,
#       'bytes_checksummed': 0,
#       'bytes_transferred': 1295410083,
#       'canceled_by_admin': None,
#       'files_transferred': 1,
#       'subtasks_canceled': 0,
#       'subtasks_retrying': 0,
#       'preserve_timestamp': False,
#       'recursive_symlinks': 'ignore',
#       'skip_source_errors': False,
#       'source_endpoint_id': '387aaf6e-3302-11ee-9200-5b20905a64b1',
#       'subtasks_succeeded': 2,
#       'nice_status_details': None,
#       'destination_endpoint': 'u_ei35ibphljgubnttgfktzs6k2m#655f5140-370f-11ee-b54c-e72de9e39f95',
#       'fail_on_quota_errors': False,
#       'destination_base_path': None,
#       'nice_status_expires_in': None,
#       'destination_endpoint_id': '300ef593-e55e-4bc1-ab21-6d26d82c3b99',
#       'subtasks_skipped_errors': 0,
#       'delete_destination_extra': False,
#       'canceled_by_admin_message': None,
#       'effective_bytes_per_second': 10545865,
#       'source_endpoint_display_name': 'PicoProbeUserDAComputer',
#       'nice_status_short_description': None,
#       'destination_endpoint_display_name': 'Gladier-PicoProbe'},
#      'action_id': '1BAqWzijmZl1t',
#      'manage_by': [],
#      'creator_id': 'urn:globus:auth:identity:cc36c658-d274-11e5-97a2-8fe5433dd97e',
#      'monitor_by': [],
#      'start_time': '2023-08-20T21:33:24.217646+00:00',
#      'state_name': 'Transfer',
#      'release_after': 'P30D',
#      'display_status': 'SUCCEEDED',
#      'completion_time': '2023-08-20T21:33:24.217675+00:00'},
#     'Publishv2Ingest': {'label': None,
#      'status': 'SUCCEEDED',
#      'details': {'state': 'SUCCESS',
#       'message': None,
#       'task_id': 'b136c9bf-c180-4f9d-875d-0fd6b3e0d039',
#       'index_id': '06625170-a9ee-4d68-b8dc-2480c9407966',
#       'task_type': 'ingest',
#       'creation_date': '2023-08-20T21:36:38',
#       'completion_date': '2023-08-20T21:36:39',
#       'state_description': 'Task succeeded',
#       'additional_details': None},
#      'action_id': '1I27dPHRGY0Q1',
#      'manage_by': [],
#      'creator_id': 'urn:globus:auth:identity:cc36c658-d274-11e5-97a2-8fe5433dd97e',
#      'monitor_by': [],
#      'start_time': '2023-08-20T21:36:39.029074+00:00',
#      'state_name': 'Publishv2Ingest',
#      'release_after': None,
#      'display_status': 'Task succeeded',
#      'completion_time': '2023-08-20T21:36:39'},
#     'TemporalImageTool': {'label': None,
#      'status': 'SUCCEEDED',
#      'details': {'result': [{'index': '06625170-a9ee-4d68-b8dc-2480c9407966',
#         'dataset': '/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164351',
#         'metadata': {'creators': [{'creatorName': 'PicoProbe Team'}],
#          'exp_type': 'picoprobe',
#          'subjects': [{'subject': 'PicoProbe'}],
#          'publisher': 'Argonne National Laboratory (ANL)',
#          'resourceType': {'resourceType': 'Dataset',
#           'resourceTypeGeneral': 'Dataset'},
#          'temporal_data': '/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164351/simulator-18-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.mp4',
#          'publicationYear': '2023',
#          'experiment_metadata': {'Signal': {'signal_type': ''},
#           'General': {'date': '2023-08-10',
#            'time': '23:19:28',
#            'title': 'Ceta',
#            'FileIO': {'0': {'io_plugin': 'hyperspy.io_plugins.emd',
#              'operation': 'load',
#              'timestamp': '2023-08-20T21:35:44.297965+00:00',
#              'hyperspy_version': '1.7.5'}},
#            'time_zone': 'UTC',
#            'original_filename': 'simulator-18-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.emd'},
#           '_HyperSpy': {'Folding': {'unfolded': False,
#             'original_shape': None,
#             'signal_unfolded': False,
#             'original_axes_manager': None}},
#           'Acquisition_instrument': {'TEM': {'Stage': {'x': -0.000247,
#              'y': 4.2e-05,
#              'z': 1.3e-05,
#              'tilt_beta': 0.0,
#              'tilt_alpha': 0.008},
#             'microscope': 'Titan',
#             'beam_energy': 300.0,
#             'camera_length': 75.0,
#             'magnification': 0.0}}},
#          'temporal_prediction_data': '/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164351/prediction-simulator-18-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.mp4'},
#         'visible_to': ['public'],
#         'destination': '/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164351',
#         'ingest_enabled': True,
#         'transfer_enabled': False,
#         'source_collection': '300ef593-e55e-4bc1-ab21-6d26d82c3b99',
#         'destination_collection': '300ef593-e55e-4bc1-ab21-6d26d82c3b99'}],
#       'results': [{'output': {'index': '06625170-a9ee-4d68-b8dc-2480c9407966',
#          'dataset': '/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164351',
#          'metadata': {'creators': [{'creatorName': 'PicoProbe Team'}],
#           'exp_type': 'picoprobe',
#           'subjects': [{'subject': 'PicoProbe'}],
#           'publisher': 'Argonne National Laboratory (ANL)',
#           'resourceType': {'resourceType': 'Dataset',
#            'resourceTypeGeneral': 'Dataset'},
#           'temporal_data': '/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164351/simulator-18-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.mp4',
#           'publicationYear': '2023',
#           'experiment_metadata': {'Signal': {'signal_type': ''},
#            'General': {'date': '2023-08-10',
#             'time': '23:19:28',
#             'title': 'Ceta',
#             'FileIO': {'0': {'io_plugin': 'hyperspy.io_plugins.emd',
#               'operation': 'load',
#               'timestamp': '2023-08-20T21:35:44.297965+00:00',
#               'hyperspy_version': '1.7.5'}},
#             'time_zone': 'UTC',
#             'original_filename': 'simulator-18-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.emd'},
#            '_HyperSpy': {'Folding': {'unfolded': False,
#              'original_shape': None,
#              'signal_unfolded': False,
#              'original_axes_manager': None}},
#            'Acquisition_instrument': {'TEM': {'Stage': {'x': -0.000247,
#               'y': 4.2e-05,
#               'z': 1.3e-05,
#               'tilt_beta': 0.0,
#               'tilt_alpha': 0.008},
#              'microscope': 'Titan',
#              'beam_energy': 300.0,
#              'camera_length': 75.0,
#              'magnification': 0.0}}},
#           'temporal_prediction_data': '/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164351/prediction-simulator-18-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.mp4'},
#          'visible_to': ['public'],
#          'destination': '/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164351',
#          'ingest_enabled': True,
#          'transfer_enabled': False,
#          'source_collection': '300ef593-e55e-4bc1-ab21-6d26d82c3b99',
#          'destination_collection': '300ef593-e55e-4bc1-ab21-6d26d82c3b99'},
#         'task_id': 'b0a81818-f879-4c1a-8015-22e23c8517f6'}]},
#      'action_id': 'tg_0715203a-6153-40f1-8fbe-64dfe9f1e131',
#      'manage_by': ['urn:globus:auth:identity:cc36c658-d274-11e5-97a2-8fe5433dd97e'],
#      'creator_id': 'urn:globus:auth:identity:cc36c658-d274-11e5-97a2-8fe5433dd97e',
#      'monitor_by': ['urn:globus:auth:identity:cc36c658-d274-11e5-97a2-8fe5433dd97e'],
#      'start_time': '2023-08-20T21:35:38.656868+00:00',
#      'state_name': 'TemporalImageTool',
#      'release_after': None,
#      'display_status': 'All tasks completed',
#      'completion_time': '2023-08-20T21:36:16.302096+00:00'},
#     'Publishv2GatherMetadata': {'label': None,
#      'status': 'SUCCEEDED',
#      'details': {'result': [{'search': {'id': 'metadata',
#          'content': {'dc': {'dates': [{'date': '2023-08-20T21:36:26.397431Z',
#              'dateType': 'Created'}],
#            'types': {'resourceType': 'Dataset',
#             'resourceTypeGeneral': 'Dataset'},
#            'titles': [{'title': '20230820-164351'}],
#            'formats': ['video/mp4',
#             'application/octet-stream',
#             'application/json'],
#            'version': '1',
#            'creators': [{'name': ''}],
#            'subjects': [],
#            'publisher': '',
#            'identifiers': [{'identifier': 'globus://300ef593-e55e-4bc1-ab21-6d26d82c3b99/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164351/20230820-164351',
#              'identifierType': 'GlobusSearchSubject'}],
#            'schemaVersion': 'http://datacite.org/schema/kernel-4',
#            'publicationYear': '2023'},
#           'files': [{'url': 'globus://300ef593-e55e-4bc1-ab21-6d26d82c3b99/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164351/20230820-164351/simulator-18-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.mp4',
#             'length': 58451712,
#             'sha256': 'e8d0aa41ecee6fcdbe3894d9535127c6bb1067ce6b5a9ad24af1b2a805d37ddd',
#             'sha512': '282a125ae0331453158b2d4795be71451ce9f0afceabdc02d5284497bb274d71b8d6eecb85b1bdc8c12743b76688fbcb83c8dddf67f1a34db19b240aeeba52bd',
#             'filename': 'simulator-18-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.mp4',
#             'mime_type': 'video/mp4'},
#            {'url': 'globus://300ef593-e55e-4bc1-ab21-6d26d82c3b99/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164351/20230820-164351/simulator-18-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.emd',
#             'length': 1295410083,
#             'sha256': 'b312fe40d8e662d376fbdd05dd162401bc8d6d9b34b27015f23b2df930e3ef46',
#             'sha512': 'e1a5c8ee3d7a4aa20adfcaab5eda0b6cdbbb3386612730591b39f6417e8d927da98c7a569a07d90e2a9eff9a32dfa67c648ef7d3b18f828409c41b5260212818',
#             'filename': 'simulator-18-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.emd',
#             'mime_type': 'application/octet-stream'},
#            {'url': 'globus://300ef593-e55e-4bc1-ab21-6d26d82c3b99/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164351/20230820-164351/prediction-simulator-18-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.mp4',
#             'length': 161135611,
#             'sha256': '1e44b065795769d538bc7acc354aaba826e06f0a9c2874ad789e4f60c9b2fd34',
#             'sha512': '27d4af685cb6749b663d9f9fc8d69813d660591ce5e1ad5e685198cf6bf4c44f908ad849cb2fe0bf7f49b20eb7607739dabfc16473beaabda95168f499a1d4a5',
#             'filename': 'prediction-simulator-18-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.mp4',
#             'mime_type': 'video/mp4'},
#            {'url': 'globus://300ef593-e55e-4bc1-ab21-6d26d82c3b99/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164351/20230820-164351/simulator-18-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.json',
#             'length': 3143,
#             'sha256': '315d513d3a6b64152fded59482a8bc1b1f7abecb69c58fd4987d109df7db3676',
#             'sha512': '1c399118fc6c7a2bbbe8732d6c8c945dd21679f1d425de2b6d628c0733d8296c9d2d68e05633bb428f23b658b955432beaed9b1fd1b24eef35eca52a7919eda1',
#             'filename': 'simulator-18-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.json',
#             'mime_type': 'application/json'}],
#           'creators': [{'creatorName': 'PicoProbe Team'}],
#           'exp_type': 'picoprobe',
#           'subjects': [{'subject': 'PicoProbe'}],
#           'publisher': 'Argonne National Laboratory (ANL)',
#           'resourceType': {'resourceType': 'Dataset',
#            'resourceTypeGeneral': 'Dataset'},
#           'temporal_data': '/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164351/simulator-18-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.mp4',
#           'publicationYear': '2023',
#           'experiment_metadata': {'Signal': {'signal_type': ''},
#            'General': {'date': '2023-08-10',
#             'time': '23:19:28',
#             'title': 'Ceta',
#             'FileIO': {'0': {'io_plugin': 'hyperspy.io_plugins.emd',
#               'operation': 'load',
#               'timestamp': '2023-08-20T21:35:44.297965+00:00',
#               'hyperspy_version': '1.7.5'}},
#             'time_zone': 'UTC',
#             'original_filename': 'simulator-18-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.emd'},
#            '_HyperSpy': {'Folding': {'unfolded': False,
#              'original_shape': None,
#              'signal_unfolded': False,
#              'original_axes_manager': None}},
#            'Acquisition_instrument': {'TEM': {'Stage': {'x': -0.000247,
#               'y': 4.2e-05,
#               'z': 1.3e-05,
#               'tilt_beta': 0.0,
#               'tilt_alpha': 0.008},
#              'microscope': 'Titan',
#              'beam_energy': 300.0,
#              'camera_length': 75.0,
#              'magnification': 0.0}}},
#           'temporal_prediction_data': '/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164351/prediction-simulator-18-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.mp4'},
#          'subject': 'globus://300ef593-e55e-4bc1-ab21-6d26d82c3b99/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164351/20230820-164351',
#          'visible_to': ['public'],
#          'search_index': '06625170-a9ee-4d68-b8dc-2480c9407966'},
#         'transfer': {'transfer_items': [{'source_path': '/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164351',
#            'destination_path': '/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164351/20230820-164351'}],
#          'source_endpoint_id': '300ef593-e55e-4bc1-ab21-6d26d82c3b99',
#          'destination_endpoint_id': '300ef593-e55e-4bc1-ab21-6d26d82c3b99'}}],
#       'results': [{'output': {'search': {'id': 'metadata',
#           'content': {'dc': {'dates': [{'date': '2023-08-20T21:36:26.397431Z',
#               'dateType': 'Created'}],
#             'types': {'resourceType': 'Dataset',
#              'resourceTypeGeneral': 'Dataset'},
#             'titles': [{'title': '20230820-164351'}],
#             'formats': ['video/mp4',
#              'application/octet-stream',
#              'application/json'],
#             'version': '1',
#             'creators': [{'name': ''}],
#             'subjects': [],
#             'publisher': '',
#             'identifiers': [{'identifier': 'globus://300ef593-e55e-4bc1-ab21-6d26d82c3b99/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164351/20230820-164351',
#               'identifierType': 'GlobusSearchSubject'}],
#             'schemaVersion': 'http://datacite.org/schema/kernel-4',
#             'publicationYear': '2023'},
#            'files': [{'url': 'globus://300ef593-e55e-4bc1-ab21-6d26d82c3b99/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-164351/20230820-164351/simulator-18-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.mp4',
#              'length': 58451712,
#              'sha256': 'e8d0aa41ecee6fcdbe3894d9535127c6bb1067ce6b5a9ad24af1b2a805d37ddd',
#              'sha512': '282a125ae0331453158b2d4795be71451ce9f0afceabdc02d5284497bb274d71b8d6eecb85b1bdc8c12743b76688fbcb83c8dddf67f1a34db19b240aeeba52bd',
# ...
#           'temporal_prediction_data': '/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-154917/prediction-simulator-0-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.mp4'},
#          'visible_to': ['public'],
#          'destination': '/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-154917',
#          'ingest_enabled': True,
#          'transfer_enabled': False,
#          'source_collection': '300ef593-e55e-4bc1-ab21-6d26d82c3b99',
#          'destination_collection': '300ef593-e55e-4bc1-ab21-6d26d82c3b99'},
#         'task_id': '14b32303-b07d-44d6-be63-44b577914b8a'}]},
#      'action_id': 'tg_586ddebd-55b6-4a09-914b-cfca2a71a07e',
#      'manage_by': ['urn:globus:auth:identity:cc36c658-d274-11e5-97a2-8fe5433dd97e'],
#      'creator_id': 'urn:globus:auth:identity:cc36c658-d274-11e5-97a2-8fe5433dd97e',
#      'monitor_by': ['urn:globus:auth:identity:cc36c658-d274-11e5-97a2-8fe5433dd97e'],
#      'start_time': '2023-08-20T20:41:37.879969+00:00',
#      'state_name': 'TemporalImageTool',
#      'release_after': None,
#      'display_status': 'All tasks completed',
#      'completion_time': '2023-08-20T20:42:50.411852+00:00'},
#     'Publishv2GatherMetadata': {'label': None,
#      'status': 'SUCCEEDED',
#      'details': {'result': [{'search': {'id': 'metadata',
#          'content': {'dc': {'dates': [{'date': '2023-08-20T20:43:01.285270Z',
#              'dateType': 'Created'}],
#            'types': {'resourceType': 'Dataset',
#             'resourceTypeGeneral': 'Dataset'},
#            'titles': [{'title': '20230820-154917'}],
#            'formats': ['application/octet-stream',
#             'video/mp4',
#             'application/json'],
#            'version': '1',
#            'creators': [{'name': ''}],
#            'subjects': [],
#            'publisher': '',
#            'identifiers': [{'identifier': 'globus://300ef593-e55e-4bc1-ab21-6d26d82c3b99/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-154917/20230820-154917',
#              'identifierType': 'GlobusSearchSubject'}],
#            'schemaVersion': 'http://datacite.org/schema/kernel-4',
#            'publicationYear': '2023'},
#           'files': [{'url': 'globus://300ef593-e55e-4bc1-ab21-6d26d82c3b99/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-154917/20230820-154917/prediction-simulator-0-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.mp4',
#             'length': 161135611,
#             'sha256': '1e44b065795769d538bc7acc354aaba826e06f0a9c2874ad789e4f60c9b2fd34',
#             'sha512': '27d4af685cb6749b663d9f9fc8d69813d660591ce5e1ad5e685198cf6bf4c44f908ad849cb2fe0bf7f49b20eb7607739dabfc16473beaabda95168f499a1d4a5',
#             'filename': 'prediction-simulator-0-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.mp4',
#             'mime_type': 'video/mp4'},
#            {'url': 'globus://300ef593-e55e-4bc1-ab21-6d26d82c3b99/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-154917/20230820-154917/simulator-0-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.emd',
#             'length': 1295410083,
#             'sha256': 'b312fe40d8e662d376fbdd05dd162401bc8d6d9b34b27015f23b2df930e3ef46',
#             'sha512': 'e1a5c8ee3d7a4aa20adfcaab5eda0b6cdbbb3386612730591b39f6417e8d927da98c7a569a07d90e2a9eff9a32dfa67c648ef7d3b18f828409c41b5260212818',
#             'filename': 'simulator-0-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.emd',
#             'mime_type': 'application/octet-stream'},
#            {'url': 'globus://300ef593-e55e-4bc1-ab21-6d26d82c3b99/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-154917/20230820-154917/simulator-0-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.json',
#             'length': 3140,
#             'sha256': '99d42e46d9d6d38943a6f6699c6e19c17b8e3d6569d4c7399a28e4429465eb4e',
#             'sha512': 'ed1bd99bd649216fdcfddb5ed20c56ec63521a8705e1b00657e03295de85652ee1caefae366a218337ea051cedfea6411805e26c928386f9fc614c7affdd20d4',
#             'filename': 'simulator-0-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.json',
#             'mime_type': 'application/json'},
#            {'url': 'globus://300ef593-e55e-4bc1-ab21-6d26d82c3b99/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-154917/20230820-154917/simulator-0-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.mp4',
#             'length': 58451712,
#             'sha256': 'e8d0aa41ecee6fcdbe3894d9535127c6bb1067ce6b5a9ad24af1b2a805d37ddd',
#             'sha512': '282a125ae0331453158b2d4795be71451ce9f0afceabdc02d5284497bb274d71b8d6eecb85b1bdc8c12743b76688fbcb83c8dddf67f1a34db19b240aeeba52bd',
#             'filename': 'simulator-0-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.mp4',
#             'mime_type': 'video/mp4'}],
#           'creators': [{'creatorName': 'PicoProbe Team'}],
#           'exp_type': 'picoprobe',
#           'subjects': [{'subject': 'PicoProbe'}],
#           'publisher': 'Argonne National Laboratory (ANL)',
#           'resourceType': {'resourceType': 'Dataset',
#            'resourceTypeGeneral': 'Dataset'},
#           'temporal_data': '/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-154917/simulator-0-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.mp4',
#           'publicationYear': '2023',
#           'experiment_metadata': {'Signal': {'signal_type': ''},
#            'General': {'date': '2023-08-10',
#             'time': '23:19:28',
#             'title': 'Ceta',
#             'FileIO': {'0': {'io_plugin': 'hyperspy.io_plugins.emd',
#               'operation': 'load',
#               'timestamp': '2023-08-20T20:41:53.419941+00:00',
#               'hyperspy_version': '1.7.5'}},
#             'time_zone': 'UTC',
#             'original_filename': 'simulator-0-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.emd'},
#            '_HyperSpy': {'Folding': {'unfolded': False,
#              'original_shape': None,
#              'signal_unfolded': False,
#              'original_axes_manager': None}},
#            'Acquisition_instrument': {'TEM': {'Stage': {'x': -0.000247,
#               'y': 4.2e-05,
#               'z': 1.3e-05,
#               'tilt_beta': 0.0,
#               'tilt_alpha': 0.008},
#              'microscope': 'Titan',
#              'beam_energy': 300.0,
#              'camera_length': 75.0,
#              'magnification': 0.0}}},
#           'temporal_prediction_data': '/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-154917/prediction-simulator-0-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.mp4'},
#          'subject': 'globus://300ef593-e55e-4bc1-ab21-6d26d82c3b99/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-154917/20230820-154917',
#          'visible_to': ['public'],
#          'search_index': '06625170-a9ee-4d68-b8dc-2480c9407966'},
#         'transfer': {'transfer_items': [{'source_path': '/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-154917',
#            'destination_path': '/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-154917/20230820-154917'}],
#          'source_endpoint_id': '300ef593-e55e-4bc1-ab21-6d26d82c3b99',
#          'destination_endpoint_id': '300ef593-e55e-4bc1-ab21-6d26d82c3b99'}}],
#       'results': [{'output': {'search': {'id': 'metadata',
#           'content': {'dc': {'dates': [{'date': '2023-08-20T20:43:01.285270Z',
#               'dateType': 'Created'}],
#             'types': {'resourceType': 'Dataset',
#              'resourceTypeGeneral': 'Dataset'},
#             'titles': [{'title': '20230820-154917'}],
#             'formats': ['application/octet-stream',
#              'video/mp4',
#              'application/json'],
#             'version': '1',
#             'creators': [{'name': ''}],
#             'subjects': [],
#             'publisher': '',
#             'identifiers': [{'identifier': 'globus://300ef593-e55e-4bc1-ab21-6d26d82c3b99/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-154917/20230820-154917',
#               'identifierType': 'GlobusSearchSubject'}],
#             'schemaVersion': 'http://datacite.org/schema/kernel-4',
#             'publicationYear': '2023'},
#            'files': [{'url': 'globus://300ef593-e55e-4bc1-ab21-6d26d82c3b99/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-154917/20230820-154917/prediction-simulator-0-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.mp4',
#              'length': 161135611,
#              'sha256': '1e44b065795769d538bc7acc354aaba826e06f0a9c2874ad789e4f60c9b2fd34',
#              'sha512': '27d4af685cb6749b663d9f9fc8d69813d660591ce5e1ad5e685198cf6bf4c44f908ad849cb2fe0bf7f49b20eb7607739dabfc16473beaabda95168f499a1d4a5',
#              'filename': 'prediction-simulator-0-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.mp4',
#              'mime_type': 'video/mp4'},
#             {'url': 'globus://300ef593-e55e-4bc1-ab21-6d26d82c3b99/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-154917/20230820-154917/simulator-0-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.emd',
#              'length': 1295410083,
#              'sha256': 'b312fe40d8e662d376fbdd05dd162401bc8d6d9b34b27015f23b2df930e3ef46',
#              'sha512': 'e1a5c8ee3d7a4aa20adfcaab5eda0b6cdbbb3386612730591b39f6417e8d927da98c7a569a07d90e2a9eff9a32dfa67c648ef7d3b18f828409c41b5260212818',
#              'filename': 'simulator-0-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.emd',
#              'mime_type': 'application/octet-stream'},
#             {'url': 'globus://300ef593-e55e-4bc1-ab21-6d26d82c3b99/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-154917/20230820-154917/simulator-0-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.json',
#              'length': 3140,
#              'sha256': '99d42e46d9d6d38943a6f6699c6e19c17b8e3d6569d4c7399a28e4429465eb4e',
#              'sha512': 'ed1bd99bd649216fdcfddb5ed20c56ec63521a8705e1b00657e03295de85652ee1caefae366a218337ea051cedfea6411805e26c928386f9fc614c7affdd20d4',
#              'filename': 'simulator-0-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.json',
#              'mime_type': 'application/json'},
#             {'url': 'globus://300ef593-e55e-4bc1-ab21-6d26d82c3b99/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-154917/20230820-154917/simulator-0-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.mp4',
#              'length': 58451712,
#              'sha256': 'e8d0aa41ecee6fcdbe3894d9535127c6bb1067ce6b5a9ad24af1b2a805d37ddd',
#              'sha512': '282a125ae0331453158b2d4795be71451ce9f0afceabdc02d5284497bb274d71b8d6eecb85b1bdc8c12743b76688fbcb83c8dddf67f1a34db19b240aeeba52bd',
#              'filename': 'simulator-0-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.mp4',
#              'mime_type': 'video/mp4'}],
#            'creators': [{'creatorName': 'PicoProbe Team'}],
#            'exp_type': 'picoprobe',
#            'subjects': [{'subject': 'PicoProbe'}],
#            'publisher': 'Argonne National Laboratory (ANL)',
#            'resourceType': {'resourceType': 'Dataset',
#             'resourceTypeGeneral': 'Dataset'},
#            'temporal_data': '/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-154917/simulator-0-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.mp4',
#            'publicationYear': '2023',
#            'experiment_metadata': {'Signal': {'signal_type': ''},
#             'General': {'date': '2023-08-10',
#              'time': '23:19:28',
#              'title': 'Ceta',
#              'FileIO': {'0': {'io_plugin': 'hyperspy.io_plugins.emd',
#                'operation': 'load',
#                'timestamp': '2023-08-20T20:41:53.419941+00:00',
#                'hyperspy_version': '1.7.5'}},
#              'time_zone': 'UTC',
#              'original_filename': 'simulator-0-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.emd'},
#             '_HyperSpy': {'Folding': {'unfolded': False,
#               'original_shape': None,
#               'signal_unfolded': False,
#               'original_axes_manager': None}},
#             'Acquisition_instrument': {'TEM': {'Stage': {'x': -0.000247,
#                'y': 4.2e-05,
#                'z': 1.3e-05,
#                'tilt_beta': 0.0,
#                'tilt_alpha': 0.008},
#               'microscope': 'Titan',
#               'beam_energy': 300.0,
#               'camera_length': 75.0,
#               'magnification': 0.0}}},
#            'temporal_prediction_data': '/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-154917/prediction-simulator-0-2023081040-700kx MultiFrams 991ms 600F Counting & FFI mode Falcon 700 kx 1819.mp4'},
#           'subject': 'globus://300ef593-e55e-4bc1-ab21-6d26d82c3b99/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-154917/20230820-154917',
#           'visible_to': ['public'],
#           'search_index': '06625170-a9ee-4d68-b8dc-2480c9407966'},
#          'transfer': {'transfer_items': [{'source_path': '/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-154917',
#             'destination_path': '/lus/eagle/projects/APSDataAnalysis/PICOPROBE/PicoProbeTestEndpoint/08-20-PicoProbeUser-temporal-production-v2/20230820-154917/20230820-154917'}],
#           'source_endpoint_id': '300ef593-e55e-4bc1-ab21-6d26d82c3b99',
#           'destination_endpoint_id': '300ef593-e55e-4bc1-ab21-6d26d82c3b99'}},
#         'task_id': '247a9c91-78e6-418b-8d34-2ed27de00b4c'}]},
#      'action_id': 'tg_54306c80-87e2-4d86-a6a1-1b04c1701c5b',
#      'manage_by': ['urn:globus:auth:identity:cc36c658-d274-11e5-97a2-8fe5433dd97e'],
#      'creator_id': 'urn:globus:auth:identity:cc36c658-d274-11e5-97a2-8fe5433dd97e',
#      'monitor_by': ['urn:globus:auth:identity:cc36c658-d274-11e5-97a2-8fe5433dd97e'],
#      'start_time': '2023-08-20T20:42:51.708988+00:00',
#      'state_name': 'Publishv2GatherMetadata',
#      'release_after': None,
#      'display_status': 'All tasks completed',
#      'completion_time': '2023-08-20T20:43:20.447963+00:00'}},
#    'description': 'The Flow run reached a successful completion state'},
#   'run_owner': 'urn:globus:auth:identity:cc36c658-d274-11e5-97a2-8fe5433dd97e',
#   'run_managers': [],
#   'run_monitors': [],
#   'user_role': 'run_owner',
#   'label': 'Temporal simulator-0-2023081040-700kx MultiFrams 991ms 600F Co..',
#   'tags': [],
#   'action_id': '595c67d7-f258-49a4-ba65-7307c58320c6',
#   'manage_by': [],
#   'monitor_by': [],
#   'created_by': 'urn:globus:auth:identity:cc36c658-d274-11e5-97a2-8fe5433dd97e'}]

# %%
len(data.flow_runs)
# Out:
# 18

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pprint import pprint
import dateutil.parser
from collections import defaultdict
import pickle

plt.rcParams['font.family'] = 'Avenir'
plt.rcParams['font.size'] = 20

class FlowInfoDataClass:
    def __init__(self):
        self.flow_id = None
        self.flow_scope = None
        self.flow_runs = []
        self.flow_order = []
        self.flow_logs = {}
        self.action_logs = {}


def get_timing_data(data: FlowInfoDataClass) -> pd.DataFrame:

    timing_data = defaultdict(list)

    for run in data.flow_runs:

        task_time = 0.0

        # Find the runtime of each task within the flow
        for task in run['details']['output'].keys():
            # Skip the input task data since it's not a task
            # Publishv2Ingest always runs in 0 seconds
            if task in ["input", "Publishv2Ingest"]:
                continue

            # Get the start and end times for the task
            start_time_str = run['details']['output'][task]['start_time']
            task_data = run['details']['output'][task]
            if task == "Transfer":
                # Note: for transfer tasks, can also get: effective_bytes_per_second
                completion_time_str = task_data["details"]['completion_time']
            elif task == "Publishv2Ingest":
                completion_time_str = task_data["details"]['completion_date']
            else:
                completion_time_str = task_data['completion_time']

            start_time = dateutil.parser.parse(start_time_str.split('+')[0])
            completion_time = dateutil.parser.parse(completion_time_str.split('+')[0])

            t_total = (completion_time - start_time).total_seconds()
            # Some tasks completion_time don't have microseconds so the start time is greater
            t_total = max(t_total, 0.0)
            task_time += t_total

            timing_data[task].append(t_total)

        # Get the total runtime of the flow
        f_start = dateutil.parser.parse(run['start_time'])
        f_end = dateutil.parser.parse(run['completion_time'])
        f_total = (f_end - f_start).total_seconds()
        
        # Get the total runtime of the active tasks
        timing_data['Active'].append(task_time)
        
        # Get the flow overhead (i.e., time not spent actively running tasks)
        timing_data["Overhead"].append(f_total - task_time)

        # Add the total flow runtime
        timing_data['Total'].append(f_total)
        
    timing_df = pd.DataFrame(timing_data)
    return timing_df

def plot_boxplot(data: pd.DataFrame) -> None:
    # Set up seaborn style
    #sns.set(style='whitegrid')
    #plt.rcParams['font.family'] = 'Avenir'
    #plt.rcParams['font.size'] = 20

    # Create a box and whisker plot
    plt.figure(figsize=(10, 6))
    sns.boxplot(data=data)
    plt.ylabel('Time (s)')
    plt.xticks(rotation=45)
    plt.grid(True)

    # Add transparency to boxplot boxes
    for patch in plt.gca().patches:
        patch.set_alpha(0.7)

    plt.tight_layout()

# %%
# Temporal flow
with open("performance_49af5d02-6d4d-4bf9-9666-813a9f2e106f.pkl", "rb") as f:
    data = pickle.load(f)

timing_df = get_timing_data(data)
timing_df.rename(columns={"TemporalImageTool": "Analysis"}, inplace=True)
timing_df.rename(columns={"Publishv2GatherMetadata": "Publication"}, inplace=True)
print(timing_df.describe())
#timing_df.hist(figsize=(10, 10))

# Create a box and whisker plot
plot_boxplot(timing_df)
plt.savefig("temporal_boxplot.pdf", bbox_inches="tight", dpi=600)

print("Median Overhead:", np.median(timing_df.Overhead))
print("Median Overhead Percent:", np.median(timing_df.Overhead / timing_df.Total))

# timing_df["Overhead_pct"] = timing_df.Overhead / timing_df.FlowTotal
# timing_df["Overhead_pct"].hist()
# Out:
#          Transfer   Analysis  Publication      Active   Overhead       Total
# count   18.000000  18.000000    18.000000   18.000000  18.000000   18.000000
# mean   118.140784  43.517992    17.845095  179.503872  44.566669  224.070541
# std      6.378009   9.649530     5.529005   14.623391  17.254268   21.220692
# min    111.920500  34.480393     9.993954  163.067952  20.238423  195.630991
# 25%    112.410824  37.670863    16.585701  169.277912  31.704745  207.702819
# 50%    114.393772  40.527507    16.978836  174.008855  45.192261  219.291088
# 75%    124.277060  45.354623    17.457138  184.220257  57.963453  237.335999
# max    128.755162  72.531883    34.163539  214.230183  72.950076  274.346484
# Median Overhead: 45.19226149999999
# Median Overhead Percent: 0.21079883178861486

# %%
# Temporal flow
with open("performance_58175c8f-e94d-4f7e-b272-aff116bf86b3.pkl", "rb") as f:
    data = pickle.load(f)

timing_df = get_timing_data(data)
timing_df.rename(columns={"HyperspectralImageTool": "Analysis"}, inplace=True)
timing_df.rename(columns={"Publishv2GatherMetadata": "Publication"}, inplace=True)
print(timing_df.describe())
#timing_df.hist(figsize=(10, 10))

# Create a box and whisker plot
plot_boxplot(timing_df)
plt.savefig("hyperspectral_boxplot.pdf", bbox_inches="tight", dpi=600)

print("Median Overhead:", np.median(timing_df.Overhead))
print("Median Overhead Percent:", np.median(timing_df.Overhead / timing_df.Total))

# timing_df["Overhead_pct"] = timing_df.Overhead / timing_df.FlowTotal
# timing_df["Overhead_pct"].hist()
# Out:
#         Transfer    Analysis  Publication      Active   Overhead       Total
# count  72.000000   72.000000    72.000000   72.000000  72.000000   72.000000
# mean   10.932426   10.982367     4.285747   26.200539  21.253055   47.453594
# std     0.372456   26.096369     1.688468   26.290603   6.642749   27.548119
# min    10.346827    3.064879     3.147762   17.056018  10.497852   29.151330
# 25%    10.622470    3.559780     3.258871   18.223015  17.041406   36.423785
# 50%    10.904214    4.427509     3.580570   19.422847  19.499208   39.891170
# 75%    11.236781    6.679052     4.354785   22.420481  24.653797   45.928132
# max    11.910999  134.807630    10.756497  149.843216  46.392676  181.401762
# Median Overhead: 19.499208000000003
# Median Overhead Percent: 0.4920743862591883

# %%
# Transfer time

# %%
import dateutil.parser
t_start = dateutil.parser.parse(data.flow_runs[0]['details']['output']['Transfer']['details']['request_time'])
t_end = dateutil.parser.parse(data.flow_runs[0]['details']['output']['Transfer']['details']['completion_time'])

# %%
(t_end - t_start).total_seconds()
# Out:
# 112.0

# %%
# Execution time

# %%
import sqlite3
import pandas as pd
# Create your connection.
cnx = sqlite3.connect('data/picoprobe_task_data.db')

df = pd.read_sql_query("SELECT * FROM transitions", cnx)

# %%
import numpy as np
np.unique(df["message"])
# Out:
# array(['execution-end', 'execution-start', 'received', 'result-received',
#        'running', 'user_fetched', 'waiting-for-launch',
#        'waiting-for-nodes'], dtype=object)

# %%
from pprint import pprint

for run in data.flow_runs:

    # Get the total runtime of the flow
    f_start = dateutil.parser.parse(run['start_time'])
    f_end = dateutil.parser.parse(run['completion_time'])
    f_total = (f_end - f_start).total_seconds()

    # Find the runtime of each task within the flow
    for task in run['details']['output'].keys():
        # Skip the input task data since it's not a task
        if task == "input":
            continue

        task_group_id = run['details']['output'][task]['action_id'].replace("tg_", "")
        task_df = df[df['task_group_uuid'] == task_group_id]

        print(task)
        print(task_df[task_df['message'] == "received"]['state_time'].values)


        t_rec = task_df[task_df['message'] == "received"]['state_time'].values[0]
        t_ret = task_df[task_df['message'] == "result-received"]['state_time'].values[0]
        t_total = (t_ret - t_rec) / 1000000000

        print(f"{task}: {t_total} seconds")

    # task_group_id = run['details']['output']['TemporalImageTool']['action_id'].replace("tg_", "")
    # #pprint(data.flow_runs[i]['details']['output'].keys()) # dict_keys(['input', 'Transfer', 'Publishv2Ingest', 'TemporalImageTool', 'Publishv2GatherMetadata'])
    
    # task_df = df[df['task_group_uuid'] == task_group_id]

    # t_rec = task_df[task_df['message'] == "received"]['state_time'].values[0]
    # t_ret = task_df[task_df['message'] == "result-received"]['state_time'].values[0]
    # t_total = (t_ret - t_rec) / 1000000000

    #print(task_df)
    pprint(run)
    break


    
    print(task_group_id)
# Out:
# Transfer
# []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[34], line 23
#      19 print(task)
#      20 print(task_df[task_df['message'] == "received"]['state_time'].values)
# ---> 23 t_rec = task_df[task_df['message'] == "received"]['state_time'].values[0]
#      24 t_ret = task_df[task_df['message'] == "result-received"]['state_time'].values[0]
#      25 t_total = (t_ret - t_rec) / 1000000000
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
tgid = data.flow_runs[0]['details']['output']['TemporalImageTool']['action_id']

task_df = df[df['task_group_uuid'] == tgid.replace("tg_", "")]

# %%
t_rec = task_df[task_df['message'] == "received"]['state_time'].values[0]
t_ret = task_df[task_df['message'] == "result-received"]['state_time'].values[0]

# %%
(t_ret - t_rec) / 1000000000
# Out:
# 31.714072342

# %%
t_es = task_df[task_df['message'] == "execution-start"]['state_time'].values[0]
t_ee = task_df[task_df['message'] == "execution-end"]['state_time'].values[0]

# %%
(t_ee - t_es) / 1000000000
# Out:
# 31.65947266

# %%
# Flow time

# %%
f_start = dateutil.parser.parse(data.flow_runs[0]['start_time'])
f_end = dateutil.parser.parse(data.flow_runs[0]['completion_time'])

# %%
(f_end - f_start).total_seconds()
# Out:
# 240.750222
